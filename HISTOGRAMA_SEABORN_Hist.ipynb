# %% [markdown]
# <a href="https://colab.research.google.com/github/tiagodados/Dados/blob/master/HISTOGRAMA_SEABORN_Hist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **AULA DESAFIO - Visualização de dados - Histograma**
#
# ---

# %% [markdown]
# > **RELEMBRANDO A SITUAÇÃO PROBLEMA**
#
# Vamos supor que você seja dono de um banco em Taiwan que oferta serviço de crédito. Você tem em mãos uma tabela em excel com dados dos clientes que contrataram o serviço de crédito.
#
# `Objetivo`: apresentar um panorama consolidado sobre a situação dos clientes no banco para o restante da empresa.
#
# `Objetivo específico`: analisar a distribuição da frequência de idade de acordo com o sexo.

# %%
# Importando as bibliotecas

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Lendo dados tabulares

credit = pd.read_excel("/content/clientes_credito.xlsx")

# %%
credit
# Out:
#        Unnamed: 0     ID  valor_credito  sexo  nivel_escolaridade  \
# 0               0      1          20000     2                   2
# 1               1      2         120000     2                   2
# 2               2      3          90000     2                   2
# 3               3      4          50000     2                   2
# 4               4      5          50000     1                   2
# ...           ...    ...            ...   ...                 ...
# 29995       29995  29996         220000     1                   3
# 29996       29996  29997         150000     1                   3
# 29997       29997  29998          30000     1                   2
# 29998       29998  29999          80000     1                   3
# 29999       29999  30000          50000     1                   2
#
#        estado_civil  idade  status_pag_set_2005  status_pag_ago_2005  \
# 0                 1     24                    2                    2
# 1                 2     26                   -1                    2
# 2                 2     34                    0                    0
# 3                 1     37                    0                    0
# 4                 1     57                   -1                    0
# ...             ...    ...                  ...                  ...
# 29995             1     39                    0                    0
# 29996             2     43                   -1                   -1
# 29997             2     37                    4                    3
# 29998             1     41                    1                   -1
# 29999             1     46                    0                    0
#
#        status_pag_jul_2005  ...  extrato_jul_2005  extrato_jun_2005  \
# 0                       -1  ...               689                 0
# 1                        0  ...              2682              3272
# 2                        0  ...             13559             14331
# 3                        0  ...             49291             28314
# 4                       -1  ...             35835             20940
# ...                    ...  ...               ...               ...
# 29995                    0  ...            208365             88004
# 29996                   -1  ...              3502              8979
# 29997                    2  ...              2758             20878
# 29998                    0  ...             76304             52774
# 29999                    0  ...             49764             36535
#
#        extrato_mai_2005  extrato_abr_2005  valor_pag_set_2005  \
# 0                     0                 0                   0
# 1                  3455              3261                   0
# 2                 14948             15549                1518
# 3                 28959             29547                2000
# 4                 19146             19131                2000
# ...                 ...               ...                 ...
# 29995             31237             15980                8500
# 29996              5190                 0                1837
# 29997             20582             19357                   0
# 29998             11855             48944               85900
# 29999             32428             15313                2078
#
#        valor_pag_ago_2005  valor_pag_jul_2005  valor_pag_jun_2005  \
# 0                     689                   0                   0
# 1                    1000                1000                1000
# 2                    1500                1000                1000
# 3                    2019                1200                1100
# 4                   36681               10000                9000
# ...                   ...                 ...                 ...
# 29995               20000                5003                3047
# 29996                3526                8998                 129
# 29997                   0               22000                4200
# 29998                3409                1178                1926
# 29999                1800                1430                1000
#
#        valor_pag_mai_2005  valor_pag_abr_2005
# 0                       0                   0
# 1                       0                2000
# 2                    1000                5000
# 3                    1069                1000
# 4                     689                 679
# ...                   ...                 ...
# 29995                5000                1000
# 29996                   0                   0
# 29997                2000                3100
# 29998               52964                1804
# 29999                1000                1000
#
# [30000 rows x 25 columns]

# %%
# Histograma

plt.figure(figsize=(15,10))

sns.histplot(credit, x="idade", hue="sexo", kde=True, palette="light:m_r"); #função para montar o histograma

plt.legend(labels=["Masculino","Feminino"]);

# 1=Masculino, 2=Feminino
